# %% [markdown]
# # Dani Olmo. WC 2022
#
# This notebook will plot some maps of actions about Dani Olmo at WC 2022.
# Why I like watching Dani Olmo at WC 2022?
#
# Because I think he creates a lot of threat: he shoots a lot, he makes passes to the dangerous zones, he actively pressing on opponents half.
# This theory I will try to prove by creating some plots:
#
# - shot map of all shots at WC 2022
# - map of passes to the final third
# - map of tackles and interceptions on opponent's half

# %% [markdown]
# ## Shot Map
#
# I will get all data for Olmo's shots on WC using statsbombpy library.

# %% [markdown]
# ### Filter matches

# %%
from statsbombpy import sb
import pandas as pd

# Get WC 2022
competitions = sb.competitions()
wc = competitions.loc[competitions["competition_id"] == 43]
wc
# Out:
# /Users/g.m.bykov/Projects/Soccermatics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id   country_name competition_name  \
# 26              43        106  International   FIFA World Cup
# 27              43          3  International   FIFA World Cup
# 28              43         55  International   FIFA World Cup
# 29              43         54  International   FIFA World Cup
# 30              43         51  International   FIFA World Cup
# 31              43        272  International   FIFA World Cup
# 32              43        270  International   FIFA World Cup
# 33              43        269  International   FIFA World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 26               male              False                       True
# 27               male              False                       True
# ...

# %%
# Get all matches of Spain
# WC 2022
matches = sb.matches(competition_id = 43, season_id = 106)
# Filter only Spain matches
spain_matches_mask = (matches["home_team"] == "Spain") | (matches["away_team"] == "Spain")
spain_matches = matches.loc[spain_matches_mask]
spain_matches["match_id"]
# Out:
# /Users/g.m.bykov/Projects/Soccermatics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# 23    3869220
# 29    3857263
# 44    3857291
# 62    3857255
# Name: match_id, dtype: int64

# %% [markdown]
# ### Create common DataFrame of shots for all selected matches

# %%
# Create function to simplify getting data of different types.
def filter_events_by_type(df, columns, type: str):
    dani_olmo_event_mask = (df["player"] == "Daniel Olmo Carvajal") & (df["type"] == type)
    return df.loc[dani_olmo_event_mask, columns]

# %%
# Get ALL events from Spain matches
all_spain_events = pd.DataFrame()

for match_id in spain_matches['match_id']:
    match_events = sb.events(match_id = match_id)
    all_spain_events = pd.concat([all_spain_events, match_events], ignore_index=True)

dani_olmo_shots = filter_events_by_type(
    all_spain_events,
    ['team', 'player', 'minute', 'second', 'type', 'location', 'shot_end_location', 'shot_outcome', 'shot_type', 'shot_statsbomb_xg'],
    "Shot"
)
dani_olmo_shots
# Out:
# /Users/g.m.bykov/Projects/Soccermatics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/g.m.bykov/Projects/Soccermatics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/g.m.bykov/Projects/Soccermatics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/g.m.bykov/Projects/Soccermatics/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#         team                player  minute  second  type       location  \
# 4618   Spain  Daniel Olmo Carvajal      54       0  Shot  [110.2, 12.6]
# 4619   Spain  Daniel Olmo Carvajal      77      37  Shot   [97.2, 31.3]
# ...
